# %%
import pandas as pd

# %%
file_path = "CICIDS2017-cleaned-for-tcn.csv"
column_to_remove = "Dst Port"

df = pd.read_csv(file_path)
df = df.drop(columns=[column_to_remove])
df.to_csv(file_path, index=False)

# %%
file_path = "CICIDS2018-cleaned-for-tcn.csv"
column_to_remove = "Dst Port"

df = pd.read_csv(file_path)
df = df.drop(columns=[column_to_remove])
df.to_csv(file_path, index=False)
